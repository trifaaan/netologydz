# %%
"""
ЗАДАНИЕ 1

"""
slovo=str(input('Введите слово:'))
n=int(len(slovo))

if n % 2 == 0 :
    k=int(n/2)
    m=k+1
    print(slovo[k-1],slovo [m-1])

else:
    a=int((n/2)+1)
    print(slovo[a-1])
# Out:
# Введите слово:qwert
# e

# %%
#ЗАДАНИЕ № 2
a = int(input("Введите число "))
sum = 0
while a != 0:
    sum += a
    a = int(input("Повторите ввод числа "))

print(sum)

# %%
# ЗАДАНИЕ № 3
boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard', 'Michael']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
if len(boys) == len(girls):
    sorted(boys)
    sorted(girls)
    i=0
    while i<= len(boys):
        print ('Идеальная пара :', sorted(boys)[i] , sorted (girls)[i])
        i=i+1
else:
    print('Внимание,кто-то может остаться без пары')

# %%
# ЗАДАНИЕ № 4
countries_temperature = [
    ['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
    ['Germany', [57.2, 55.4, 59, 59, 53.6]],
    ['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
    ['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4]]
]
print('Cредняя температура в странах:')
print('Thailand - ', round((sum(countries_temperature[0][1])/len(countries_temperature[0][1])-32)/1.8,1), 'C')
print('Germany - ', round((sum(countries_temperature[1][1])/len(countries_temperature[1][1])-32)/1.8,1), 'C')
print('Russia - ', round((sum(countries_temperature[2][1])/len(countries_temperature[2][1])-32)/1.8,1), 'C')
print('Poland - ', round((sum(countries_temperature[3][1])/len(countries_temperature[3][1])-32)/1.8,1), 'C')
# Out:
# Cредняя температура в странах:
# Thailand -  23.9 C
# Germany -  13.8 C
# Russia -  3.7 C
# Poland -  12.0 C
